# %%
import MeCab
import time
import random
import numpy as np
import time

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def tokenize(sentence):
    """日本語の文を形態素の列に分割する関数

    :param sentence: str, 日本語の文
    :return tokenized_sentence: list of str, 形態素のリスト
    """
    node = tagger.parse(sentence)
    node = node.split("\n")
    tokenized_sentence = []
    for i in range(len(node)):
        feature = node[i].split("\t")
        if feature[0] == "EOS":
            # 文が終わったら終了
            break
        # 分割された形態素を追加
        tokenized_sentence.append(feature[0])
    return tokenized_sentence

# %%
import pandas as pd

# %%
def load_data(path):
    """『こころ』を読み込むための関数

    :param path: str, 『こころ』のパス
    :return text: list of list of str, 各文がトークナイズされた『こころ』
    """
    text = []
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            line = tokenize(line)
            text.append(line)
    return text

# %%
tagger = MeCab.Tagger("-Ochasen")
text = load_data("dataset/Material/recipes2.txt")

# %%
text[10000]
# Out:
# ['型',
#  'に',
#  'クッキング',
#  'シート',
#  'を',
#  '敷き',
#  'ます',
#  '。',
#  'オーブン',
#  'を',
#  '１',
#  '８',
#  '０',
#  '℃',
#  'で',
#  '余熱',
#  '開始',
#  '。',
#  '板',
#  'チョコ',
#  'の',
#  '場合',
#  'は',
#  '適度',
#  'な',
#  '大き',
#  'さ',
#  'に',
#  '砕き',
#  'ます',
#  '。',
#  'ボール',
#  'に',
#  'を',
#  '計量',
#  'し',
#  'て',
#  '、',
#  'スプーン',
#  'で',
#  'かき混ぜ',
#  'て',
#  '、',
#  '粉',
#  '類',
#  'と',
#  '砂糖',
#  'と',
#  '抹茶',
#  'を',
#  '混ざり',
#  '合わせ',
#  'て',
#  'から',
#  '、',
#  '２',
#  '～',
#  '３',
#  '回',
#  'ふるっ',
#  'て',
#  'おき',
#  'ます',
#  '。',
#  'ボール',
#  'に',
#  'ふるっ',
#  'た',
#  'を',
#  '入れ',
#  'て',
#  '、',
#  '真ん中',
#  'を',
#  'くぼま',
#  'せ',
#  'ます',
#  '。',
#  'の',
#  '卵',
#  'を',
#  '別',
#  'の',
#  'ボール',
#  'に',
#  'とい',
#  'て',
#  'おき',
#  'ます',
#  '。',
#  '３',
#  '．',
#  'の',
#  'くぼま',
#  'せ',
#  'た',
#  'ところ',
#  'に',
#  'を',
#  '入れ',
#  'ます',
#  '。',
#  'ゴム',
#  'ベラ',
#  'で',
#  '、',
#  'サックリ',
#  'と',
#  '切り',
#  '混ぜ',
#  'し',
#  'て',
#  '、',
#  '少し',
#  'なじん',
#  'で',
#  'き',
#  'て',
#  '写真',
#  'の',
#  '様',
#  'な',
#  '位',
#  'に',
#  'なっ',
#  'たら',
#  '一旦',
#  '混ぜる',
#  'の',
#  'を',
#  'ストップ',
#  'し',
#  'ます',
#  '。',
#  '５',
#  '．',
#  'に',
#  'あらかじめ',
#  '砕い',
#  'て',
#  'おい',
#  'た',
#  'チョコレート',
#  'を',
#  '加え',
#  'ます',
#  '。',
#  '再度',
#  '、',
#  'サックリ',
#  'と',
#  '切り',
#  '混ぜ',
#  'し',
#  'て',
#  '、',
#  '粉',
#  'っぽ',
#  'さ',
#  'が',
#  '無くなっ',
#  'たら',
#  '混ぜる',
#  'の',
#  'を',
#  'ストップ',
#  'し',
#  'ます',
#  '。',
#  '用意',
#  'し',
#  'て',
#  'おい',
#  'た',
#  '型',
#  'に',
#  '流し',
#  'いれ',
#  'て',
#  '、',
#  '何',
#  '度',
#  'か',
#  '少し',
#  '上',
#  'に',
#  '持ち上げ',
#  'て',
#  '真下',
#  'に',
#  '落とし',
#  'て',
#  '空気抜き',
#  'を',
#  'し',
#  'ます',
#  '。',
#  '１',
#  '８',
#  '０',
#  '℃',
#  'の',
#  'オーブン',
#  'で',
#  '約',
#  '４',
#  '５',
#  '分',
#  '焼き',
#  'ます',
#  '。',
#  '（',
#  'お',
#  '手持ち',
#  'の',
#  'オーブン',
#  'で',
#  '調整',
#  'し',
#  'て',
#  '下さい',
#  '。',
#  '）',
#  '焼き',
#  'あがり',
#  'まし',
#  'た',
#  '♬',
#  '真ん中',
#  'に',
#  '竹',
#  'ぐし',
#  'を',
#  'さし',
#  'て',
#  '、',
#  '何',
#  'も',
#  '付い',
#  'て',
#  'こ',
#  'なけれ',
#  'ば',
#  '焼き',
#  '上がり',
#  'です',
#  '。',
#  '型',
#  'から',
#  'すぐ',
#  'に',
#  '取り出し',
#  'て',
#  '、',
#  'クッキング',
#  'シート',
#  'を',
#  '外し',
#  '、',
#  'ケーキ',
#  'クーラー',
#  '等',
#  'に',
#  '乗せ',
#  'て',
#  'ください',
#  '。',
#  '最近',
#  'は',
#  '、',
#  '板',
#  'チョコ',
#  'も',
#  '色々',
#  'な',
#  '味',
#  'が',
#  '販売',
#  'さ',
#  'れ',
#  'て',
#  'いる',
#  'ので',
#  '、',
#  'お',
#  '好み',
#  'の',
#  'もの',
#  'で',
#  'どうぞ',
#  '♬',
#  'もちろん',
#  'チョコ',
#  'チップ',
#  'でも',
#  '大丈夫',
#  '❀']

# %%
class Vocab(object):
    """語彙を管理するためのクラス"""
    def __init__(self, word2id={}):
        """
        :param word2id: 単語(str)をインデックス(int)に変換する辞書
        """
        self.word2id = dict(word2id)
        self.id2word = {v: k for k, v in self.word2id.items()}    

    def build_vocab(self, sentences, min_count=1):
        """コーパスから語彙の辞書を構築するメソッド

        :param sentences: list of list of str, コーパス
        :param min_count: int, 辞書に含める単語の最小出現回数
        """
        # 各単語の出現回数をカウントする辞書を作成します
        word_counter = {}
        for sentence in sentences:
            for word in sentence:
                # dict.get(key, 0)はdictにkeyがあればdict[key]を、なければ0を返すメソッドです
                word_counter[word] = word_counter.get(word, 0) + 1

        # min_count回以上出現する単語のみ語彙に加えます
        # 出現回数の高い単語から順にword2idに追加していきます
        # 出現回数に-1をかけた値でsortすることで出現回数の降順になるようにしています
        for word, count in sorted(word_counter.items(), key=lambda x: -x[1]):
            if count < min_count:
                break
            _id = len(self.word2id)
            self.word2id.setdefault(word, _id)
            self.id2word[_id] = word

        # 語彙に含まれる単語の出現回数を保持します（あとで使います）
        self.raw_vocab = {w: word_counter[w] for w in self.word2id.keys() if w in word_counter}

# %%
def compute_word_similarity(embedding_path, word, n):
    """
    与えられた単語に最も似ている単語とcos類似度を返す関数

    :param embedding_path: str, 保存した埋め込み層のパラメータのパス
    :param word: str, 単語
    :param n: int
    :return out: str, 上位n個の類似単語とそのcos類似度
    """
    embedding = torch.load(embedding_path)

    # 単語ベクトルを全て単位ベクトルにする
    norm = np.linalg.norm(embedding, ord=2, axis=1, keepdims=True)
    norm = np.where(norm==0, 1, norm) # 0で割ることを避ける
    embedding /= norm
    e = embedding[vocab.word2id[word]]

    # 単語ベクトル同士のcos類似度を計算する
    cos_sim = np.dot(embedding, e.reshape(-1, 1)).reshape(-1,)
    most_sim = np.argsort(cos_sim)[::-1][1:n+1] # 自分は除く
    most_sim_words = [vocab.id2word[_id] for _id in most_sim]
    top_cos_sim = cos_sim[most_sim]
    out = ", ".join([w+"({:.4f})".format(v) for w, v in zip(most_sim_words, top_cos_sim)])
    return out

# %%
def cosine_similarity(e1, e2):
    """
    与えられた単語に最も似ている単語とcos類似度を返す関数

    :param embedding_path: str, 保存した埋め込み層のパラメータのパス
    :param word: str, 単語
    :param n: int
    :return out: str, 上位n個の類似単語とそのcos類似度
    """
    """
    embedding = torch.load(embedding_path)

    # 単語ベクトルを全て単位ベクトルにする
    norm = np.linalg.norm(embedding, ord=2, axis=1, keepdims=True)
    norm = np.where(norm==0, 1, norm) # 0で割ることを避ける
    embedding /= norm
    e = embedding[vocab.word2id[word]]
    """
    norm = np.linalg.norm(e2, ord=2)
    norm = np.where(norm==0, 1, norm) # 0で割ることを避ける
    e2 /= norm
    
    # 単語ベクトル同士のcos類似度を計算する
    cos_sim = np.dot(e1, np.transpose(e2)).reshape(-1,)
    #cos_sim = np.dot(e1, e2.reshape(-1, 1)).reshape(-1,)
    
    '''
    most_sim = np.argsort(cos_sim)[::-1][1:n+1] # 自分は除く
    most_sim_words = [vocab.id2word[_id] for _id in most_sim]
    top_cos_sim = cos_sim[most_sim]
    out = ", ".join([w+"({:.4f})".format(v) for w, v in zip(most_sim_words, top_cos_sim)])

    '''
    return cos_sim

# %%
# 特殊なトークンとそのIDは事前に定義しておきます。
PAD_TOKEN = '<PAD>' # あとで説明するpaddingに使います
UNK_TOKEN = '<UNK>' # 辞書にない単語は全てこのUNKトークンに置き換えます。(UNKの由来はunkownです)
PAD = 0 # <PAD>のID
UNK = 1 # <UNK>のID

# %%
# 辞書の初期化
word2id = {
    PAD_TOKEN: PAD,
    UNK_TOKEN: UNK,
}

# 辞書に含める単語の最低出現回数
# 今回はコーパスのサイズが小さいので、全ての単語を辞書に含めることにします
MIN_COUNT = 2

# %%
vocab = Vocab(word2id=word2id)
vocab.build_vocab(text, min_count=MIN_COUNT)

# %%
def sentence_to_ids(vocab, sen):
    """
    単語のリストをIDのリストに変換する関数

    :param vocab: class `Vocab` object
    :param sen: list of str, 文を分かち書きして得られた単語のリスト
    :return out: list of int, 単語IDのリスト
    """
    out = [vocab.word2id.get(word, UNK) for word in sen] # 辞書にない単語にはUNKのIDを割り振ります
    return out

# %%
# 日本語のテキストを単語IDに変換します。
id_text = [sentence_to_ids(vocab, sen) for sen in text]

# %%
print(text[2])
print(id_text[2])
# Out:
# ['豚肉', 'の', '表面', 'を', 'キッチン', 'ペーパー', 'で', '丁寧', 'に', '水分', 'を', '拭き取っ', 'て', 'ください', '粗塩', 'を', '丁寧', 'に', 'まんべんなく', '豚肉', 'に', '擦り込み', 'ます', 'この', '分量', 'の', '肉', 'なら', '３', '５', 'ｇ', 'ぐらい', 'です', 'いい', '塩', 'ほど', '旨く', 'なる', 'って', 'いい', 'ます', 'ね', 'じっくり', '熟成', 'さ', 'せ', 'たい', 'から', '、', 'キッチン', 'ペーパー', 'で', '豚肉', 'を', '包み', '、', 'その', '上', 'から', 'ラップ', 'で', '包み', 'ます', 'そして', '冷蔵庫', 'で', '熟成', 'です', '１', '週間', '位', 'は', 'ドリップ', 'が', '出', 'て', 'き', 'ます', 'から', '、', '毎日', 'キッチン', 'ペーパー', 'と', 'ラップ', 'は', '交換', 'し', 'て', '下さい', 'この', '手間', 'が', '豚肉', 'を', '美味しく', 'し', 'ます', '豚肉', 'が', '小さけれ', 'ば', 'すぐ', 'に', '熟成', 'し', 'ます', 'が', '、', 'この', '状態', 'で', '約', '３', '週間', '経っ', 'て', 'い', 'ます', 'スライス', 'し', 'て', '熱湯', 'で', '茹で', 'て', 'ゆず', '味噌', 'で', 'いただき', 'まし', 'た']
# [224, 7, 220, 2, 444, 326, 8, 980, 3, 155, 2, 2490, 6, 123, 4462, 2, 980, 3, 782, 224, 3, 4767, 12, 243, 164, 7, 100, 251, 45, 59, 497, 337, 28, 258, 31, 116, 6412, 71, 1331, 258, 12, 189, 647, 3360, 27, 63, 804, 38, 5, 444, 326, 8, 224, 2, 499, 5, 166, 51, 38, 119, 8, 499, 12, 1019, 137, 8, 3360, 28, 18, 1501, 141, 10, 1, 13, 225, 6, 88, 12, 38, 5, 4768, 444, 326, 14, 119, 10, 5679, 9, 6, 167, 243, 2305, 13, 224, 2, 1058, 9, 12, 224, 13, 4769, 76, 466, 3, 3360, 9, 12, 13, 5, 243, 578, 8, 237, 45, 1501, 1600, 6, 149, 12, 153, 9, 6, 503, 8, 91, 6, 747, 409, 8, 694, 87, 15]

# %%
def pad_seq(seq, max_length):
    """Paddingを行う関数

    :param seq: list of int, 単語のインデックスのリスト
    :param max_length: int, バッチ内の系列の最大長
    :return seq: list of int, 単語のインデックスのリスト
    """
    seq += [PAD for i in range(max_length - len(seq))]
    return seq

# %%
embedding_path = "recipe_cbow_embedding_600b.pth"
embedding = torch.load(embedding_path)
print(embedding.shape)
# Out:
# (7432, 300)

# %%
# 単語ベクトルを全て単位ベクトルにする
norm = np.linalg.norm(embedding, ord=2, axis=1, keepdims=True)
norm = np.where(norm==0, 1, norm) # 0で割ることを避ける
embedding /= norm
e1 = embedding[vocab.word2id['こしょう']]
e2= embedding[vocab.word2id['大根']]

# %%
cosine_similarity(e1, e2)
# Out:
# array([0.81496495], dtype=float32)

# %%
clusterVec = [embedding[0]]     # tracks sum of vectors in a cluster
clusterIdx = []    # array of index arrays. e.g. [[1, 3, 5], [2, 4, 6]]
ncluster = 0

# %%
# probablity to create a new table if new customer
# is not strongly "similar" to any existing table
pnew = 1.0/ (1 + ncluster)  
N = len(embedding)
#rands = random.rand(N)         # N rand variables sampled from U(0, 1)
print(N)
# Out:
# 7432

# %%
v = embedding[0]
sim = cosine_similarity(v, clusterVec[0])
print(sim)
# Out:
# [1.]

# %%
 for i in range(N):
    maxSim = -float('inf')
    maxIdx = 0
    v = embedding[i]
    for j in range(ncluster):
        sim = cosine_similarity(v, clusterVec[j])
        if sim > maxSim:
            maxIdx = j
            maxSim = sim
    if maxSim < pnew:
        if random.random() < pnew:
            clusterVec.append(v)
            clusterIdx.append([i])
            ncluster += 1
            pnew = 1.0 / (1 + ncluster)
            continue
    clusterVec[maxIdx] = clusterVec[maxIdx] +v
    clusterIdx[maxIdx].append(i)

# %%
print(len(clusterIdx))
# Out:
# 20

# %%
clusterIdx[1]
# Out:
# [2,
#  3,
#  518,
#  811,
#  991,
#  1327,
#  1536,
#  1559,
#  1570,
#  1610,
#  1629,
#  1656,
#  1698,
#  1729,
#  1736,
#  1747,
#  1776,
#  1816,
#  1819,
#  1843,
#  1874,
#  1880,
#  1930,
#  2027,
#  2055,
#  2097,
#  2098,
#  2134,
#  2137,
#  2179,
#  2206,
#  2231,
#  2328,
#  2360,
#  2363,
#  2369,
#  2393,
#  2414,
#  2457,
#  2488,
#  2515,
#  2531,
#  2581,
#  2615,
#  2629,
#  2650,
#  2677,
#  2719,
#  2729,
#  2737,
#  2753,
#  2772,
#  2781,
#  2831,
#  2832,
#  2880,
#  2882,
#  2947,
#  2962,
#  2964,
#  2986,
#  3015,
#  3049,
#  3055,
#  3056,
#  3075,
#  3099,
#  3106,
#  3109,
#  3122,
#  3142,
#  3184,
#  3260,
#  3264,
#  3279,
#  3282,
#  3292,
#  3313,
#  3344,
#  3354,
#  3362,
#  3364,
#  3443,
#  3500,
#  3507,
#  3576,
#  3602,
#  3679,
#  3691,
#  3707,
#  3715,
#  3720,
#  3736,
#  3744,
#  3746,
#  3749,
#  3766,
#  3787,
#  3826,
#  3859,
#  3945,
#  3948,
#  4069,
#  4077,
#  4087,
#  4089,
#  4101,
#  4138,
#  4174,
#  4178,
#  4180,
#  4190,
#  4191,
#  4193,
#  4239,
#  4244,
#  4251,
#  4255,
#  4266,
#  4269,
#  4292,
#  4300,
#  4386,
#  4389,
#  4397,
#  4409,
#  4438,
#  4454,
#  4464,
#  4467,
#  4501,
#  4556,
#  4598,
#  4620,
#  4653,
#  4718,
#  4773,
#  4834,
#  4877,
#  4879,
#  4915,
#  4940,
#  4972,
#  4989,
#  5008,
#  5019,
#  5049,
#  5099,
#  5101,
#  5161,
#  5163,
#  5171,
#  5206,
#  5237,
#  5243,
#  5248,
#  5275,
#  5292,
#  5302,
#  5336,
#  5377,
#  5402,
#  5465,
#  5509,
#  5516,
#  5521,
#  5530,
#  5555,
#  5634,
#  5650,
#  5651,
#  5660,
#  5705,
#  5744,
#  5746,
#  5753,
#  5780,
#  5794,
#  5810,
#  5811,
#  5814,
#  5823,
#  5869,
#  5883,
#  5894,
#  5898,
#  5902,
#  5908,
#  5909,
#  5963,
#  6009,
#  6011,
#  6026,
#  6031,
#  6044,
#  6049,
#  6074,
#  6094,
#  6114,
#  6115,
#  6169,
#  6181,
#  6255,
#  6267,
#  6268,
#  6275,
#  6290,
#  6297,
#  6299,
#  6305,
#  6317,
#  6333,
#  6334,
#  6371,
#  6384,
#  6392,
#  6465,
#  6491,
#  6494,
#  6541,
#  6547,
#  6555,
#  6583,
#  6586,
#  6611,
#  6656,
#  6666,
#  6667,
#  6684,
#  6685,
#  6686,
#  6695,
#  6699,
#  6703,
#  6732,
#  6751,
#  6752,
#  6759,
#  6767,
#  6787,
#  6809,
#  6832,
#  6833,
#  6835,
#  6842,
#  6858,
#  6890,
#  6900,
#  6938,
#  6982,
#  7015,
#  7038,
#  7049,
#  7057,
#  7083,
#  7095,
#  7107,
#  7139,
#  7156,
#  7168,
#  7281,
#  7321,
#  7346,
#  7347,
#  7348,
#  7362,
#  7372,
#  7386,
#  7396,
#  7402,
#  7423]

# %%
clusterIdx[5]
# Out:
# [304,
#  407,
#  437,
#  450,
#  482,
#  483,
#  498,
#  521,
#  527,
#  530,
#  540,
#  553,
#  556,
#  598,
#  667,
#  669,
#  822,
#  856,
#  910,
#  911,
#  954,
#  1059,
#  1103,
#  1114,
#  1261,
#  1431,
#  1507,
#  1567,
#  1644,
#  1655,
#  1664,
#  1667,
#  1752,
#  1800,
#  1956,
#  1995,
#  2035,
#  2060,
#  2091,
#  2143,
#  2170,
#  2215,
#  2242,
#  2261,
#  2265,
#  2300,
#  2325,
#  2329,
#  2377,
#  2416,
#  2429,
#  2463,
#  2507,
#  2567,
#  2570,
#  2577,
#  2599,
#  2639,
#  2654,
#  2672,
#  2702,
#  2744,
#  2745,
#  2782,
#  2798,
#  2853,
#  2857,
#  2877,
#  2890,
#  2897,
#  2898,
#  2926,
#  2944,
#  2958,
#  2965,
#  2966,
#  3005,
#  3114,
#  3130,
#  3144,
#  3150,
#  3161,
#  3177,
#  3225,
#  3228,
#  3278,
#  3300,
#  3301,
#  3342,
#  3352,
#  3399,
#  3426,
#  3432,
#  3441,
#  3457,
#  3488,
#  3523,
#  3531,
#  3534,
#  3607,
#  3617,
#  3633,
#  3688,
#  3737,
#  3739,
#  3752,
#  3755,
#  3779,
#  3830,
#  3834,
#  3872,
#  3920,
#  3924,
#  3943,
#  3960,
#  3965,
#  3968,
#  4003,
#  4023,
#  4036,
#  4045,
#  4082,
#  4094,
#  4095,
#  4151,
#  4153,
#  4158,
#  4162,
#  4168,
#  4175,
#  4206,
#  4207,
#  4214,
#  4224,
#  4252,
#  4256,
#  4270,
#  4280,
#  4284,
#  4290,
#  4315,
#  4341,
#  4345,
#  4346,
#  4350,
#  4352,
#  4379,
#  4404,
#  4526,
#  4527,
#  4530,
#  4540,
#  4548,
#  4588,
#  4664,
#  4692,
#  4698,
#  4710,
#  4782,
#  4792,
#  4799,
#  4800,
#  4829,
#  4842,
#  4881,
#  4916,
#  4943,
#  4977,
#  5007,
#  5045,
#  5076,
#  5107,
#  5139,
#  5142,
#  5160,
#  5210,
#  5226,
#  5238,
#  5240,
#  5266,
#  5278,
#  5301,
#  5308,
#  5317,
#  5356,
#  5375,
#  5406,
#  5423,
#  5440,
#  5441,
#  5483,
#  5507,
#  5532,
#  5536,
#  5542,
#  5543,
#  5572,
#  5577,
#  5589,
#  5638,
#  5685,
#  5686,
#  5731,
#  5738,
#  5769,
#  5774,
#  5784,
#  5830,
#  5833,
#  5854,
#  5904,
#  5928,
#  5946,
#  5958,
#  5967,
#  5986,
#  5988,
#  5992,
#  5994,
#  6015,
#  6021,
#  6047,
#  6056,
#  6103,
#  6123,
#  6142,
#  6154,
#  6206,
#  6213,
#  6223,
#  6321,
#  6326,
#  6346,
#  6348,
#  6404,
#  6436,
#  6438,
#  6443,
#  6462,
#  6472,
#  6476,
#  6480,
#  6486,
#  6498,
#  6563,
#  6567,
#  6576,
#  6580,
#  6636,
#  6664,
#  6689,
#  6707,
#  6719,
#  6728,
#  6754,
#  6802,
#  6803,
#  6838,
#  6856,
#  6861,
#  6886,
#  6898,
#  6929,
#  6960,
#  6965,
#  7002,
#  7010,
#  7022,
#  7044,
#  7065,
#  7097,
#  7121,
#  7150,
#  7190,
#  7196,
#  7197,
#  7201,
#  7202,
#  7206,
#  7225,
#  7231,
#  7268,
#  7358,
#  7390,
#  7392,
#  7399,
#  7420]

# %%
for i in range(0,len(clusterIdx)):
    print(len(clusterIdx[i]))
# Out:
# 320
# 271
# 365
# 344
# 2922
# 287
# 260
# 271
# 261
# 252
# 248
# 248
# 249
# 211
# 226
# 196
# 185
# 180
# 98
# 38

# %%
for i in range(0, len(clusterIdx[4])):
    print(vocab.id2word[clusterIdx[4][i]])
# Out:
# ます
# ！
# ♪
# ので
# き
# なっ
# 色
# 器
# ボウル
# ボール
# かける
# みじん切り
# 全体
# ソース
# オイル
# コショウ
# 水気
# い
# 酒
# 水分
# 中
# 等分
# 乗せ
# 下
# ※
# 分量
# 大
# その
# オリーブ
# →
# トマト
# 】
# 残り
# 【
# 止め
# 具
# サラダ油
# だ
# 全て
# 耐熱
# ベーコン
# 熱
# 香り
# 目
# 容器
# いる
# いい
# 盛り
# ねぎ
# にんじん
# 適当
# 取り
# 分け
# 洗っ
# 薄切り
# 好き
# 量
# しんなり
# 用
# 並べ
# 揚げ
# ネギ
# 生クリーム
# 抜き
# 胡椒
# パン
# じゃがいも
# 米
# 薄力粉
# ７
# 両面
# 厚
# 写真
# つい
# 形
# 美味しい
# 葉
# チョコ
# 幅
# 〜
# 状
# いく
# スープ
# クリーム
# 大さじ
# 一口
# 白
# 一緒
# ｃｍ
# レモン
# すり
# 湯
# たっぷり
# だし
# なく
# さっと
# ＾
# うち
# 板
# 180
# ず
# 昆布
# ペーパー
# ニンニク
# 長
# おろし
# クッキング
# そこ
# 生姜
# 煮汁
# ぐらい
# 感じ
# つける
# 茹でる
# 等
# 輪切り
# 粗
# 良く
# すべて
# ミキサー
# 気
# 使用
# 入り
# でも
# まぶし
# 丸め
# しょうゆ
# とき
# 見
# のせる
# 次
# 全部
# 味付け
# カップ
# コンソメ
# 冷やし
# 包丁
# 敷い
# 使っ
# 塗り
# 回し
# とろみ
# より
# ＯＫ
# 洗い
# 縦
# っと
# 豚
# みりん
# 更に
# 準備
# 巻い
# 泡立て
# 素
# 焼け
# 口
# 盛り付け
# 付け
# 私
# 良い
# れ
# 日
# ，
# スプーン
# 煮込む
# むき
# 味噌
# ．
# 余熱
# パセリ
# 落とし
# ザル
# 出し
# 同じ
# 上がっ
# しょうが
# 海苔
# 食べる
# 卵白
# つゆ
# 類
# つく
# タレ
# こんがり
# 取っ
# 溶き
# 注意
# 大きめ
# 間
# さらし
# ふた
# 6
# 溶け
# 刻ん
# 順
# ③
# ハム
# かき混ぜ
# 漬け
# キッチン
# こ
# ケチャップ
# 保存
# 仕上げ
# トッピング
# ､
# 串
# 揚げる
# ドレッシング
# 調整
# 広げ
# 敷き
# ごま
# 放置
# アク
# 振り
# 圧力
# ◎
# 焦げ目
# すぐ
# 8
# 置い
# ゴマ
# 冷ます
# 置き
# 芯
# 冷凍
# ほうれん草
# 麺
# もち
# 晩
# ピーマン
# ところ
# 前
# りんご
# ビニール
# ましょ
# ある
# むい
# 底
# 細切り
# 印
# あと
# パン粉
# ひき
# 炊飯
# 黒豆
# ｇ
# 包み
# 焦げ
# 様
# 溶い
# 熱湯
# ごぼう
# くり
# やわらかく
# まぜ
# ブロッコリー
# 小
# とり
# 40
# たまねぎ
# 沸かし
# mm
# 乗せる
# にかけて
# 液
# 材
# 移し
# ほぐし
# 熱い
# あけ
# メレンゲ
# 用意
# 途中
# 生
# ジャガイモ
# こと
# 種
# 伸ばし
# 絞り
# ここ
# あげ
# さっ
# :
# 蒸し
# めん
# だら
# ざる
# ㎝
# 盛っ
# 振っ
# 絞っ
# 止める
# グラニュー
# g
# 本
# カレー
# かぼちゃ
# 足し
# 残っ
# 真ん中
# 溶かす
# きゅうり
# 食パン
# 椎茸
# なくなる
# …
# 使い
# 散らし
# 混ざっ
# さつまいも
# 整え
# 数
# 200
# 和え
# さかな
# ベラ
# しばらく
# 状態
# ひき肉
# 塗っ
# 竹
# サイズ
# ケーキ
# こんな
# ござい
# 少量
# 先
# でき
# 煮立っ
# 端
# お鍋
# 以上
# フォーク
# 乾燥
# 裏返し
# 水切り
# 出る
# 柚子
# ふるっ
# おいしい
# 絡め
# ひと
# 斜め
# 室温
# その後
# ご
# 170
# ゆでる
# 長ネギ
# とっ
# あん
# 7
# ふっ
# ひっくり返し
# 小さじ
# 調節
# バナナ
# 油揚げ
# 包ん
# 魚
# もやし
# 多め
# 使う
# ･
# 通り
# ゴム
# め
# クリームチーズ
# 潰し
# 大丈夫
# 付い
# 缶
# にかけ
# 豆
# そう
# 平ら
# のり
# ドライ
# また
# ありがとう
# じっくり
# 半
# パウダー
# マーガリン
# 泡だて
# 泡
# 小さく
# 取る
# ふりかけ
# 何
# 空気
# 倍
# セロリ
# 割り
# 巻く
# 再び
# 水溶き
# それぞれ
# 里芋
# 煮詰め
# どうぞ
# ❤
# フタ
# だし汁
# 簡単
# しいたけ
# まぶす
# 流し入れ
# ポン酢
# 蒸し焼き
# ちょっと
# チョコレート
# 様子
# くる
# ざく
# とる
# 適量
# 栗
# 調え
# ワイン
# しめじ
# 取れ
# 塗る
# 玉葱
# 添え
# いただき
# 味見
# ため
# あり
# 手前
# 綺麗
# もう
# ゼラチン
# 通る
# 調える
# タイム
# 布巾
# 牛肉
# 物
# 完全
# レタス
# なめらか
# ほう
# cc
# イースト
# 半量
# 直前
# きれい
# 刻み
# すぎ
# 温める
# きっ
# ④
# こんにゃく
# 並べる
# ニンジン
# 変わっ
# 鮭
# 人
# 他
# サッと
# 整える
# ベンチ
# 飾り
# 二
# エビ
# 感
# 下味
# パイ
# ふるい
# ミリ
# 開け
# くるみ
# ふり
# 和える
# ゆず
# アルミホイル
# ヨーグルト
# スポンジ
# 2010
# 白っぽく
# ちぎっ
# 豆乳
# 荒
# 頂き
# なじま
# 取り出す
# フード
# 残し
# 思い
# 終わり
# 干し
# ひたひた
# 海老
# 練り
# 12
# シロップ
# ｗ
# 唐辛子
# 穴
# 丸く
# 乱切り
# す
# こん
# 25
# 休ま
# 固まっ
# 小口切り
# 水菜
# まんべんなく
# 箸
# ９
# W
# 横
# 杯
# 普通
# セット
# あく
# 台
# たま
# 木
# "
# ホワイト
# こちら
# プロセッサー
# 入っ
# 煮詰める
# 温度
# 刺し
# まぜる
# バラ
# たい
# 常温
# ゆっくり
# それ
# ごはん
# つ
# やすく
# 加減
# 片面
# あわせ
# ハンド
# 』
# 盛る
# コーン
# 600
# 手早く
# ひと煮立ち
# ｍｍ
# ×
# サラダ
# 『
# 周り
# え
# 玉子
# 冷やす
# 殻
# アーモンド
# ピザ
# 泡立てる
# その間
# 剥い
# 再度
# 刻む
# まわし
# ？
# 衣
# 弱
# 水洗い
# 一度
# 固め
# 茎
# レンコン
# こね
# 上がり
# ー
# 捨て
# !!
# 滑らか
# 外し
# アレンジ
# トロ
# ～♪
# 短冊
# キムチ
# わ
# 面
# バニラ
# 切り分け
# ジャム
# 抜く
# 注ぎ
# 粒
# さらす
# バット
# かぶせ
# きり
# 合わせる
# 振る
# ガス
# ウインナー
# とろける
# いれる
# からめ
# ある程度
# ぽ
# 載せ
# シナモン
# クッキー
# 500
# レーズン
# 上げ
# 芋
# 固
# ら
# 煮立た
# 時々
# にくい
# よい
# 参考
# 弁当
# きつね
# 始め
# 通す
# 出す
# 足り
# 強力粉
# 指
# 納豆
# によって
# 餃子
# 網
# じゃ
# 黄身
# 付く
# 浸し
# 重ね
# 100
# 伸ばす
# ベーキングパウダー
# ふる
# 麺棒
# 同様
# 炊く
# でし
# 戻す
# イカ
# 煮込ん
# ツナ
# しき
# 次に
# 手羽
# 半熟
# 圧
# ラム
# あら
# 50
# 大根おろし
# 薄い
# 引き
# く
# 葱
# 詰め
# 蒸し器
# 《
# 》
# Ａ
# もっ
# Ｂ
# 冷水
# ペースト
# ケース
# スタート
# 振りかけ
# ＋
# 冷凍庫
# きのこ
# 中華
# 斜め切り
# くし
# つぶす
# 解凍
# 背
# 通し
# ~
# ＞
# 鰹節
# のばし
# 打ち
# アルミ
# 笑
# 丁寧
# ｃｃ
# なくなっ
# 胡麻
# 弱め
# 側
# タマネギ
# 又は
# 都度
# 白身
# 余分
# っぽ
# 取り除く
# エリンギ
# 蒸す
# 絡める
# 返し
# 散らす
# o
# 炊き
# 三
# マヨ
# あまり
# かまぼこ
# くるくる
# 所
# まとめ
# 追加
# オリーブ油
# おろす
# アボカド
# 立て
# かき混ぜる
# ＜
# 少なく
# そして
# 分割
# 終了
# 取り除き
# 細く
# もう一度
# 終わっ
# 大きく
# こねる
# 風
# ゴマ油
# 硬
# 年
# 焦がさ
# 一気に
# 灰汁
# 目安
# 余っ
# もみ
# ✿
# タッパー
# 温かい
# づつ
# きる
# ゴムべら
# なし
# 爪
# もも肉
# 切り込み
# ホットケーキミックス
# 流し込み
# ミ
# 中身
# くれ
# 美味しく
# 分の
# 鷹
# 必要
# 小豆
# 我が家
# ⑤
# 溶ける
# 蓮根
# HB
# 分間
# おにぎり
# 手順
# 参照
# w
# 最初
# 残る
# 七草
# グラタン
# コーヒー
# はちみつ
# 濡れ
# 付き
# 抜い
# 炒り
# 市販
# コース
# みじん
# 瓶
# 小さい
# 煮え
# 煮立て
# ざっと
# 砕い
# 牡蠣
# なべ
# 成形
# いちょう
# 合
# 感謝
# Ｈ
# 込み
# 捏ね
# 甘
# ニラ
# 白い
# ぬるま湯
# かつお
# ♬
# 閉じ
# 立つ
# として
# 落し蓋
# しっとり
# 引い
# 自然
# あがり
# 湯煎
# 梅
# 顔
# ブラックペッパー
# 固く
# 転がし
# 飛ばし
# 棒状
# 押し
# 洗う
# サツマイモ
# 温まっ
# 練る
# かぶ
# 馴染ま
# 薄め
# トースト
# いつも
# 揉み
# べら
# まだ
# カリカリ
# 十分
# しまう
# なれ
# ミックス
# フルーツ
# 崩れ
# ざっくり
# 可
# 追記
# 骨
# つき
# クルミ
# 皆様
# っ
# ハート
# 湯せん
# 耳
# 果汁
# あっ
# 順に
# 均一
# けど
# 9
# 挽肉
# とれ
# 裏ごし
# かぶる
# スライサー
# 厚め
# 内側
# 来
# 飛ばす
# 春雨
# 加
# 丸める
# はんぺん
# つまみ
# 照り
# すくい
# れる
# 掛け
# あげる
# 青
# わさび
# 苺
# きん
# くぐら
# 煮立ち
# パラパラ
# 筋
# 落とす
# 薄
# 切り落とし
# 長い
# グリル
# まとまっ
# 切れ
# ^^
# 寒天
# 広げる
# 中心
# 円
# ♥
# キツネ
# 椀
# わけ
# ちぎり
# 表示
# リンゴ
# 一旦
# 便利
# だれ
# 脂
# 粘り
# 的
# 閉じる
# カリッ
# 内
# 代わり
# 割
# しい
# 付ける
# 直径
# ま
# 三つ葉
# 潰す
# 出来上がっ
# いちご
# 均等
# ポイント
# マカロニ
# パン生地
# 蜂蜜
# 押さえ
# 分ける
# 固める
# 為
# 丸
# 食
# ガーリック
# 菜
# テフロン
# マスタード
# じゃが芋
# 開始
# 実
# ㎜
# 強め
# 醤
# からめる
# 牛
# 下げ
# 料理
# すぎる
# 明太子
# 爪楊枝
# まな板
# 匙
# 飾る
# ひじき
# なじん
# タネ
# ふやかし
# 胡桃
# 上下
# 紙
# さつま芋
# 胸
# あんこ
# 出来る
# １つ
# そっと
# すくっ
# 茄子
# のみ
# ／
# 卵焼き
# ロースト
# 軸
# 挽き肉
# 有難う
# かつお節
# かなり
# ナッツ
# 作業
# 盛り付ける
# スイッチ
# 合わ
# すれ
# 各
# 半日
# 片方
# ミニ
# ちゃ
# 柔らか
# 濃い
# カスタード
# ダマ
# タルト
# って
# もどし
# みかん
# 元
# ホイップ
# 釜
# 多い
# 190
# 糸
# 下ろし
# ひっくり返す
# はずし
# 花
# ぶし
# 塩水
# 開い
# 少なめ
# 際
# 赤
# Ｗ
# 回っ
# 透き通っ
# 顆粒
# フツ
# しまい
# 小さな
# 分離
# つくれ
# 消し
# 成型
# 割っ
# 繰り返す
# 入る
# 11
# 13
# -
# 裏
# たて
# 画像
# できる
# タコ
# ミンチ
# 順番
# なかっ
# 蒸気
# 飾っ
# 作り方
# ワタ
# 蒸らし
# さや
# 流し込む
# 粗く
# いり
# 石づき
# 注ぐ
# 青のり
# 変え
# 繊維
# 汚れ
# 鉄板
# 取り除い
# 35
# 長芋
# 処理
# 手のひら
# あたため
# 豆板
# ダシ
# カマ
# 厚み
# 焼
# フライ
# むく
# 春巻き
# 変わる
# 揚げ油
# ラー油
# 立っ
# られ
# 寝かせる
# 熱々
# 外側
# 菜箸
# さし
# もしくは
# +
# 頭
# 万能
# ふりかける
# いためる
# パウンド
# ナス
# 仕上がり
# オススメ
# 試し
# 始める
# スパゲティ
# 大豆
# ↑
# 優しく
# つくる
# 大きな
# ；
# 絡ま
# 一番
# ﾌﾗｲﾊﾟﾝ
# ２つ
# 60
# わかめ
# ラーメン
# 馴染ん
# あらかじめ
# とか
# 寿司
# 叩い
# 完了
# は種
# ぶり
# 翌日
# 両端
# 塩もみ
# 細かい
# 白く
# 春菊
# のばす
# 具合
# 寝かせ
# バージョン
# 大体
# 18
# 塊
# 小房
# プレート
# 込む
# おすすめ
# 漬ける
# だいたい
# 薄皮
# オイスターソース
# 被せ
# 飯
# 切り餅
# なるべく
# たらし
# 丼
# 週間
# 茸
# 繰り返し
# 楽
# 切り分ける
# ポリ
# 浸る
# あさり
# 膨らん
# げん
# 大き目
# 太め
# 高野
# 楊枝
# 肉汁
# ジュース
# 冷え
# 合い
# シメジ
# 計量
# ぐるぐる
# たけ
# 一つ
# 敷き詰め
# －
# チップ
# ささ
# はがし
# 鳥
# ジップロック
# )。
# (^
# 掲載
# 梅干し
# パルメザンチーズ
# ふるう
# 召し上がり
# 機能
# やっ
# 側面
# ブリ
# ホタテ
# 和風
# きな粉
# そば
# 甘酢
# 切り目
# ml
# たくさん
# ベーカリー
# 張り
# スイッチオン
# 変更
# ピーラー
# 巻きす
# ＝
# ととのえ
# 臭み
# 彩り
# 添える
# アスパラ
# サンド
# プリン
# 固まり
# 紅茶
# ホット
# 粉末
# 霧吹き
# [
# 美味
# つめ
# FP
# モモ
# かるく
# 経っ
# 250
# 焼成
# ⑥
# うつし
# B
# みたい
# り
# 厚手
# 流水
# ホイル
# 45
# ミート
# ち
# 火加減
# 箱
# 固い
# めん棒
# ダレ
# つくり
# け
# ベビー
# グツグツ
# ローリエ
# ショウガ
# 拭き取り
# 浮い
# ハーブ
# 数の子
# 150
# デコレーション
# 氷水
# 無
# 柔らかい
# ♫
# m
# ω
# 麩
# 刷毛
# ちゃん
# かけれ
# さいの目
# 割れ
# 乾い
# 模様
# 使え
# 貝
# とっても
# 移す
# 通れ
# 輪ゴム
# 変わり
# 微塵
# ウィンナー
# 可愛い
# かぶせる
# 重なら
# 軟らかく
# プードル
# シチュー
# とても
# 日本
# 密閉
# 茶碗
# 絹
# 人肌
# 可能
# オクラ
# 勧め
# 本当に
# ガラスープ
# 保温
# つか
# 同
# すり鉢
# 濃
# 青ネギ
# ぐつぐつ
# 必ず
# 更
# ビスケット
# 子供
# 芽
# 両手
# ふっくら
# ようじ
# 割りほぐし
# ギュッ
# 深
# 甘み
# タイプ
# チリ
# 流し入れる
# そぼろ
# 舞
# 設定
# 溶きほぐし
# ぶつ切り
# 長方形
# みそ
# まとまり
# ４つ
# よーく
# とろ
# つつ
# ソテー
# (^^)
# 時点
# 無くなっ
# 薄焼き
# まずは
# 除い
# 今度
# 22
# 茶漉
# 薄口
# 撹拌
# 林檎
# 振りかける
# 取り分け
# 沸かす
# 見た目
# しぼっ
# ⑦
# あたり
# 切り身
# させ
# 赤ワイン
# 胡麻油
# 多少
# 静か
# もん
# 根元
# まき
# 切
# 目玉焼き
# 牛蒡
# という
# 利用
# 間隔
# 薬味
# ベーグル
# ^)
# 濡らし
# 垂らし
# ちょうど
# すくう
# クルクル
# 煮物
# 味の素
# ほんの
# グルグル
# まわり
# により
# 少ない
# ふつふつ
# じ
# つぶさ
# 前日
# 面倒
# シーチキン
# ♪※
# しらす
# ブロック
# とめる
# もと
# 温
# 金柑
# 果肉
# 折り
# 捏ねる
# きなこ
# とじ
# 白髪
# この間
# くっつか
# ゼリー
# ㌢
# 折っ
# 細
# 後で
# 買っ
# パリ
# ちらし
# あける
# こう
# 缶詰
# まっ
# ♪）
# 一味
# ぬり
# 下ごしらえ
# マフィン
# 黒糖
# 消毒
# シイタケ
# 適宜
# どんぶり
# 摩り
# られる
# ぶ
# ならし
# 空
# 開き
# クレイジーソルト
# アイス
# 平たく
# 右
# 炒
# まとめる
# すり混ぜる
# サラダオイル
# 番
# 拭き
# 炊い
# ひとつまみ
# 漬け込む
# 回り
# フレーク
# ://
# 味噌汁
# ひとつ
# おかげ
# 24
# おせ
# イチョウ
# 崩し
# 皆さん
# ひとまとめ
# 交互
# ゆであがっ
# ココット
# 16
# 家庭
# だま
# ライス
# 持ち
# おいしく
# http
# プラス
# 箇所
# 甘い
# 煮詰まっ
# 左右
# 熱く
# 頂く
# もっと
# 予め
# 辛
# すっ
# 素早く
# 挽き
# 漉し
# 茶こし
# ”
# かかっ
# 極
# 頃
# お好み焼き
# 削ぎ
# 硬く
# 素敵
# サクサク
# 玄米
# 補足
# 染み
# ひたすら
# インゲン
# 全
# とろけ
# 大人
# へた
# 切り口
# 辛い
# 混ざる
# リーフ
# 減っ
# 楕円
# しまっ
# たたい
# びき
# 天ぷら
# っぽい
# ナツメグ
# 逆さ
# さい
# かま
# 押す
# 円形
# きくらげ
# 細い
# シュガー
# ほとんど
# できれ
# 寄せ
# 続い
# 落ち
# 載せる
# なおし
# ﾁｰｽﾞ
# 重石
# 流す
# 丸い
# ととのえる
# 無く
# うっすら
# ぬらし
# 無し
# くださっ
# 硬め
# 脂肪
# ↓
# しら
# ベジタブル
# ウスターソース
# ティー
# 剥く
# 記載
# ズッキーニ
# 食材
# 通常
# 内臓
# ふるって
# ザク
# 細長く
# 17
# かきまぜ
# うまく
# できるだけ
# サラン
# むね
# しめ
# 切ら
# 十字
# 210
# 焼肉
# ホール
# 切込み
# 再
# さんま
# 鯖
# ぴったり
# 塩気
# 縁
# 湯通し
# 持っ
# 低速
# たたき
# 黒砂糖
# ふわっと
# 硬い
# やさしく
# ほぼ
# 温泉
# とろとろ
# 断面
# 根菜
# か所
# 桜
# っぽく
# 左
# 合う
# ずらし
# ムラ
# つ折り
# 除き
# H
# マリネ
# ぬれ
# どう
# 直し
# 香ばしい
# 煮沸
# やる
# 練ら
# 重ねる
# 胡瓜
# 子
# 裂い
# 艶
# 背わた
# 美味しかっ
# ぬっ
# 中温
# BP
# あえて
# マシュマロ
# キウイ
# 家
# ｵｰﾌﾞﾝ
# ブランデー
# ろ
# くっつけ
# 沿っ
# 不要
# 辛味
# ﾊﾞﾀｰ
# を通して
# ぎゅっと
# ｍｌ
# 濾し
# そぎ
# 反対
# 持ち替え
# 売っ
# 挟み
# 閉め
# 音
# 辺
# 段
# 揉む
# コ
# 高温
# すこし
# もむ
# 浸す
# ﾎﾞｳﾙ
# 強く
# ぎり
# とも
# 空気抜き
# 小分け
# いか
# 薄けれ
# バサミ
# 若干
# プロ
# ～！
# 膨らむ
# きっちり
# 上げる
# もし
# 持ち上げ
# お茶
# ちゃっ
# とぎ
# 親指
# ほん
# 違い
# あつあつ
# EX
# ぽん
# アサリ
# 開ける
# しそ
# べ
# 氷
# 残す
# ふち
# 格子
# 青い
# フランス
# たく
# さっぱり
# 省略
# かきまぜる
# 220
# ‥
# いっ
# おかず
# あ
# コチュジャン
# 隠れる
# かた
# 絶対
# 色づい
# 手間
# 早め
# 濃厚
# こそげ
# 小鍋
# 重曹
# 落としぶた
# モード
# オムレツ
# くちなし
# コク
# なくなり
# 張っ
# 押さえる
# 房
# 柿
# 使わ
# ピンク
# 山
# 麹
# 塗
# 700
# げ
# 割合
# 増し
# 蒟蒻
# カリ
# たき
# 焦げる
# 色づく
# 続ける
# バレンタイン
# ⑧
# ほぐれ
# 下がっ
# 塩加減
# 食卓
# 力
# 取れる
# 待っ
# まぐろ
# きざみ
# に対して
# 拍子
# ピーナッツ
# パチ
# フー
# 炊きあがっ
# カキ
# 竹輪
# 土台
# コーティング
# 濃く
# アツアツ
# ススメ
# 揚がっ
# ニッスイ
# イタリアン
# ハサミ
# しれ
# はさむ
# やわらか
# チェック
# バルサミコ
# くっつい
# 空け
# くわえ
# ぬる
# ごまめ
# 早い
# もどす
# 別々
# レン
# 線
# 計
# シュー
# サワークリーム
# ゲン
# レバー
# ぜんざい
# 周囲
# つまん
# 形成
# 火力
# Special
# 立てる
# 果物
# 山椒
# クーラー
# 良し
# 湯銭
# タイミング
# 絡ん
# リキュール
# アルデンテ
# 朝
# クラッカー
# ブルーベリー
# 入ら
# 小判
# 紹介
# どおり
# くっつき
# あい
# Ｃ
# 潰さ
# 二つ
# おけ
# 押し付ける
# 90
# 超
# ピクルス
# ときほぐし
# 液体
# 上がる
# 三角形
# とかし
# 端っこ
# まわっ
# みる
# 凍っ
# 基本
# さとう
# スキムミルク
# ＩＤ
# さまし
# さして
# 雑煮
# 合せ
# ゆ
# 失敗
# 寝かす
# すり混ぜ
# はさん
# 銀杏
# モツ
# とけ
# 口金
# ブレンダー
# 切り干し
# 巻き込ん
# 水あめ
# シフォン
# コレ
# 酵母
# ごめんなさい
# 飛ぶ
# UP
# しみこま
# ふき取る
# とん
# 向き
# 返す
# パイナップル
# 飴
# 上白
# 甘く
# 糊
# 血
# プレゼント
# 任せ
# 品
# 計り
# 控えめ
# パリッ
# 切れる
# 御飯
# 段階
# 乗っけ
# バッグ
# 黄色
# 早
# チャーハン
# さめ
# なんか
# ガーゼ
# くっつける
# まろやか
# につけ
# さつま揚げ
# 鬼
# 星
# おかゆ
# 手の平
# ロー
# び
# カード
# いりこ
# なじみ
# 向け
# ペーパータオル
# 冷
# いただけ
# ▲
# 23
# 漬物
# ツヤ
# タマゴ
# 掛ける
# 付か
# 表
# 四角
# ザッ
# こんなに
# 茶色
# 歯ごたえ
# 除く
# 同時に
# 切り落とす
# 炒っ
# シャキシャキ
# 馴染む
# からし
# プレーン
# ボイル
# 描く
# リエ
# 全粒粉
# 型紙
# とりだし
# 直ぐ
# もも
# オレオ
# 防ぐ
# 抑え
# 旨い
# 密封
# あめ色
# めがけ
# フレンチ
# O
# 持た
# マッシュポテト
# 片
# ≫
# ^
# 最近
# ㍉
# 27
# ザクザク
# ぎ
# コネ
# 十
# ときどき
# ボタン
# 一部
# ON
# 膨らみ
# くりぬい
# おこ
# &
# 29
# 絡まっ
# コリアンダー
# くわい
# こす
# 寝かし
# 茶色く
# 離し
# ヶ所
# ぜひ
# 焼き上げ
# お腹
# せれ
# 拍子木
# あえ
# あじ
# こぎ
# ピューレ
# 普段
# かり
# 見る
# みなさん
# タイマー
# ねかせる
# ホウレンソウ
# 使える
# いろいろ
# 巻
# カイワレ
# 触っ
# 太い
# ネ
# ノ
# かさ
# タラ
# 解し
# 沸
# 系
# 金時
# 人さし指
# からま
# 食べ頃
# よそっ
# 書く
# オニオン
# 巻け
# 苦味
# 引く
# かかる
# 点火
# スパム
# そっ
# あさつき
# ふり入れ
# かえ
# Ｍ
# 嬉しい
# サクッ
# みこん
# 鮮やか
# ３つ
# すき焼き
# わかし
# 蜜
# 当て
# とばし
# もつ
# 同じく
# 暖め
# 覆い
# シリコン
# 構い
# 淵
# ヶ月
# 観音開き
# なん
# 保管
# 膨れ
# ヘルシー
# 散らせ
# 擦り
# あたためる
# 欲しい
# ▼
# 70
# 具に
# しゃぶしゃぶ
# 雑炊
# 混ぜ合わす
# 電気
# 蒸発
# かかり
# お菓子
# 夏
# ビール
# 向こう
# 行う
# 以降
# 焼き肉
# 無理
# 外皮
# しょ
# よそい
# たこ焼き
# 合図
# (^-^)
# トロリ
# 木綿
# まるめ
# つや
# 多目
# 傾け
# 握っ
# イイ
# スルメ
# 甘煮
# ザックリ
# ぬ
# ただ
# 雑穀
# 狐
# 頑張っ
# 高速
# 染みる
# 可愛く
# ＠
# 研ぎ
# kcal
# マン
# リング
# みつば
# うろこ
# 過熱
# 表記
# しゃも
# 正方形
# 四
# ｸﾘｰﾑ
# 留める
# やい
# こぼし
# 柄
# ∀
# ♪(
# とろ火
# 動かし
# 百
# ゆかり
# GOOD
# たわし
# グレープフルーツ
# 文字
# はがれ
# 合え
# ♪
# なめ
# 煮つめ
# うえ
# 触ら
# かわり
# 麻
# ええ
# ✱
# わり
# むら
# しく
# つやつや
# おいしかっ
# 折り込み
# パンチ
# アスパラガス
# 安定
# ほうれんそう
# 吹きこぼれ
# フィンガー
# 終え
# 赤く
# 栄養
# 19
# 方向
# 紅生姜
# せり
# 重量
# ﾏﾖﾈｰｽﾞ
# チャーシュー
# トマトケチャップ
# 田作り
# 結ぶ
# 新しい
# ピック
# 庫
# 尚
# 食べごろ
# 応じ
# きぬ
# ﾗｯﾌﾟ
# グリーンピース
# パルメザン
# ス
# 夜
# ウエイパー
# さす
# ⑪
# 溶きほぐす
# ザーサイ
# 明太
# 減る
# 折りたたみ
# ふくらん
# 紅しょうが
# 差
# 方々
# ばらし
# オッケー
# ストック
# はず
# かじき
# ＵＰ
# マフィンカップ
# 熟成
# そろえ
# ぶくぶく
# つくっ
# 175
# 床
# ちょい
# recipe
# だり
# 石
# 短縮
# スパゲッティー
# ｣
# ブラウン
# ♫♬
# タジン
# そい
# 彡
# くるっ
# 平
# 味醂
# かわいい
# メモリ
# 同士
# ^)／
# おとし
# 手軽
# クレソン
# ヤーコン
# 冬
# 急ぐ
# すばやく
# 続き
# 敷きつめ
# めっちゃ
# ワット
# 炊きたて
# 筑前
# 縛り
# 通ら
# (^-^;)
# はがす
# )》
# 絞り出す
# ミント
# 消え
# ｽﾗｲｽ
# ひとくち
# 応用
# クランブル
# ジッパー
# イモ
# バケット
# 屋根
# 甘辛
# ｏ
# ギュ
# こっち
# はっ
# 勿論
# 大蒜
# 作ら
# きゃ
# お茶漬け
# ポッカレモン
# さく
# つくね
# ＣＣ
# 対
# デミグラスソース
# 煮つめる
# アンパン
# 焦がし
# 編
# 良かっ
# きら
# 冷える
# 薩摩芋
# 入れれ
# ザラメ
# よかっ
# なんて
# 内皮
# ฺ
# オン
# ビタミン
# そろえる
# もらい
# 車
# 余計
# たたく
# つ折
# 千切
# わける
# あぶら
# 書ける
# はる
# クルッ
# いら
# 余裕
# 見栄え
# いろんな
# ´
# 110
# ワサビ
# ふきとり
# ひっくりかえし
# 大目
# 見直し
# 張る
# ちょこっと
# 浅い
# 煮豆
# カレイ
# ふ
# 南蛮
# わら
# カサ
# フライドオニオン
# 回る
# 出来上がる
# 立た
# 茹
# 易く
# %
# 魚介
# 閉める
# キャンディ
# ひとかたまり
# 鰤
# 六
# 血合い
# らしい
# 手持ち
# 弾力
# プレーンヨーグルト
# マッチ
# クレソル
# ジュッ
# ひよこ
# けれど
# ☝
# 心
# ’
# かため
# 春
# 致し
# 折込
# 香味
# ｿｰｽ
# 事前
# 伸び
# 姉妹
# すりつぶし
# づらい
# 一回り
# そえ
# 出し汁
# こそ
# 重く
# ざら
# きれ
# かく
# in
# °
# 膨らま
# 一晩
# 窪ま
# 潰れ
# 黄金
# しみ込み
# ギリギリ
# カカオ
# 人前
# やめ
# マドレーヌ
# ぐるり
# 菓子
# Ｌ
# ぉく
# スパイシー
# ガーッ
# 縦横
# 馴染み
# 少な目
# 友達
# ｿｰｾｰｼﾞ
# 左手
# ニソ
# 残り物
# 剥がれ
# うふ
# からませ
# オレンジピール
# カッテージチーズ
# 先程
# クタクタ
# 蒸かし
# 鳴っ
# やり方
# 染み込み
# ﾋﾞﾆｰﾙ
# 戻り
# 羊羹
# jp
# 室
# 板ずり
# マロニー
# みつ
# ゜
# サンマ
# はりつけ
# スチーム
# 見立て
# まく
# 対角線
# かたくり粉
# 外れ
# よけれ
# ねかす
# _
# 当分
# 埋め
# 色付け
# 湯葉
# キッシュ
# よる
# 脱水
# カチカチ
# 842254
# 本当は
# ソフト
# CC
# つつみ
# 合いびき
# ものの
# イチジク
# ついてる
# ティースプーン
# 滑ら
# 綿棒
# 辛み
# ｂ
# 予防
# 埋める
# 安く
# すき
# イングリッシュマフィン
# 伊達巻
# 別に
# 煮あがっ
# 小骨
# まんま
# 120
# 案外
# ーー
# ℓ
# 炊きあがり
# 堅
# 関節
# おこわ
# カルシウム
# 食事
# 慌て
# 枝
# ボロボロ
# やら
# ぽろぽろ
# 人数
# 全く
# 折りたたん
# ぷっくり
# さらっ
# ➟
# コマ
# 確かめ
# 度目
# 飲み
# ミック
# もどき
# デミ
# ふく
# 合える
# まぜあわせる
# のに
# ポタージュ
# 大雑把
# しみこん
# マカロン
# 焼売
# 行っ
# 楽ちん
# みなさま
# タピオカ
# 軽
# お蔭
# ｀)
# 少なけれ
# どこ
# 白餡
# ＃
# 必須
# 小ぶり
# ！)
# いし
# くれぐれも
# きつ
# 記事
# 覗い
# クローブ
# すくい上げ
# トッポギ
# 水飴
# 直
# ～❤
# いわれ
# ベタ
# そんなに
# ぜ
# メモ
# 回転
# だって
# ランチ
# 右側
# 平気
# 煮詰めれ
# ねー
# 搾り出し
# 鮮度
# にぎる
# 下記
# 燻製
# カバー
# ばら
# はいっ
# 八つ
# 浮かん
# ジャン
# スモーク
# 包め
# ｸﾞﾗﾆｭｰ
# 軽い
# 掛けれ
# 遍
# 八幡
# なぁ
# 手抜き
# よそ
# 白みそ
# 青物
# クリチ
# シラス
# Ｄ
# 食う
# 軟飯
# 低め
# 決める
# 着く
# 折り込む
# ツメ
# 晒し
# ),
# 鰆
# 沈み
# テンメンジャン
# 55
# 朝食
# 冷たく
# そそぎ
# 年版
# ドン
# 焦がす
# いわし
# ﾀﾚ
# サルサ
# ]…
# Ｉ
# 壊れ
# ･･
# クチナシ
# 上がれ
# クミンシード
# パラ
# 上面
# 炙っ
# 法
# のぞき
# 薔薇
# 併せ
# 煮含める
# 効か
# 鯵
# 回分
# くり抜く
# 今
# 上澄み
# ハラペーニョ
# 練り上げる
# ［
# まとまれ
# ガンガン
# 点々
# にくかっ
# 求肥
# ぞ
# ご覧
# 篩い
# ℃(
# スライド
# 糠
# ビタ
# 切りそろえる
# ﾏﾖ
# 可愛
# ふわり
# 浮かべ
# 赤み
# ６つ
# 半々
# ﾄﾞﾗｲｲｰｽﾄ
# さつま
# 茹だっ
# タイ
# 低い
# 840720
# ｶｯﾄ
# 開か
# まん丸
# 選択
# ルクエ
# スコーン
# 手土産
# がん
# テスト
# 切り離す
# ｴﾋﾞ
# つぎ
# 詰め込む
# カゴ
# ♡
# シーザー
# 力強く
# vr
# ふるふる
# 岩塩
# こだま
# しり
# 陶器
# 温まり
# サヤエンドウ
# イン
# 旗
# むべ
# ﾌﾞﾗｯｸﾍﾟｯﾊﾟｰ
# ♪＊
# 渦巻き
# ﾊﾞﾅﾅ
# ヤング
# 布き
# どっさり
# 商店
# モンブラン
# つるつる
# もどっ
# ゆでこぼす
# 放り込む
# チゲ
# 質
# すりまぜる
# 新た
# しみこむ
# ボトル
# リッツ
# つぶつぶ
# 食欲
# あったまっ
# にる
# ずり
# 円錐
# 二分
# 閉じ込め
# 置け
# ふくらみ
# たべ
# 心から
# 干す
# 残さ
# 手鍋
# 盛り上がっ
# 弱める
# おし
# 扇形
# 表情
# 空ける
# ｡※
# きの
# まわる
# メイン
# まんじゅう
# すると
# ｏｋ
# 鋏
# どろ
# ぎりに
# 揚がり
# ビニル
# 特有
# 申し上げ
# 吹き寄せ
# 完熟
# プラスチック
# ルゥ
# づくり
# (^^;
# トリュフ
# 繋ぎ
# ゆする
# フォルダ
# 室内
# はったい
# 薄目
# ポケット
# っぱなし
# サンタ
# 下拵え
# 濁ら
# 下がれ
# 折り紙
# 生臭
# くるま
# 推奨
# ただし
# 分厚く
# レモンペッパー
# 中途半端
# ヤンニョム
# 売ら
# 太けれ
# ♪♪♪
# youtube
# 280
# 有
# 補給
# タワシ
# カフェ
# バー
# 目分量
# トンカツ
# ）⑥
# かわい
# (._.)
# 次第
# つつき
# 京都
# 控え目
# からむ
# ひれ
# 混ん
# くぎ
# けし
# くま
# 一滴
# ホッ
# かりかり
# 炊ける
# 手ごろ
# 煮出し
# 溶けれ
# 焼き餅
# ひっくりかえす
# きゅっと
# プ
# わらび
# ぴょうを
# 乗る
# 根気
# トップページ
# 零れ
# ER
# ホワイトリカー
# ついて
# にぎっ
# 高める
# 外観
# ！"
# ナゲット
# 指示
# 重層
# 沈殿
# Point
# 復活
# 一層
# 背骨
# 抽出
# ぱりぱり
# もらう
# トローリ
# 抑える
# スイートチョコレート
# やっと
# 押して
# 株
# かおり
# ヒダ
# まるごと
# ネバネバ
# ポテトチップス
# ぷくぷく
# どうしても
# 切り出す
# カラー
# 甜麺
# ℃→
# かたれ
# 道具
# モッツァレラチーズ
# トマトピューレ
# 鏡餅
# 市松
# 先ず
# おしゃれ
# 冷す
# 大まか
# ねぇ
# 土地
# ｻｲｽﾞ
# センス
# ゝ
# ズ
# カルピス
# 本来
# 吸い取っ
# .
# ラカント
# あめ
# 煮含め
# トック
# マダイ
# 鮪
# 絡まり
# ♪✿
# ﾛｰｽﾄ
# 拡げ
# ぴ
# クタッ
# うら
# 不可
# じゃん
# アール
# ｶﾘｶﾘ
# 397
# 代える
# 温水
# 团
# 県
# 引っ張る
# 混合
# プスプス
# 押し出し
# ドライイーストコース
# バジルオイル
# ～※
# ティファール
# 添加
# うっかり
# べたつい
# 鞘
# ごみ
# 本位
# 擦り込む
# つや出し
# 食用
# 美味い
# そえる
# 上等
# ‼
# ロック
# おじぎ
# 巻きずし
# レアチーズ
# 味わっ
# グルテン
# 風通し
# なさっ
# 流出
# ウインナー・
# もうすぐ
# ずっしり
# バジル・
# 散りばめ
# 双子
# 置き換える
# ずし
# しかし
# 支え
# マグネシウム
# ヘモグロビン
# 酸素
# 堪能
# 蕗
# 鰊
# チラシ
# 仕込ん
# ！③
# 経済
# ベジ
# 子玉
# ）④
# すくいあげる
# 財
# かざっ
# 参
# とうもろこし
# マルチブレンダー
# !(^^)!
# ラフランス
# 流れる
# mg
# φ
# 色目
# 黄な粉
# 取り置く
# 潰れる
# レモンピール
# 揚
# ㍗
# パルス
# フィーリング
# 済ませる
# ずく
# ルバーブ
# ｶﾎﾞﾁｬ
# ボケ
# σ
# チンッ
# 240
# ブレンド
# モッチリ
# 揚がれ
# プラチョコ
# タコス
# サーブ
# わい
# またまた
# コンテスト
# まゆ
# レンチ
# (´∀`)
# ポップコーン
# 継ぎ目
# ※①
# ♪↑
# コフタ
# そら豆
# チョ
# 感動
# riohiro
# バタール
# 下絵
# ｼｰﾄ
# 発見
# とぶ
# 年生
# オイシイ
# ｈ
# 押し麦
# パンタグラフ
